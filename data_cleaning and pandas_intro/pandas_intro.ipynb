# %%
import pandas as pd
import numpy as np

# %%
data_list = [
    ['John', 30, 68.5, True, 95.5],
    ['Alice', 25, 63.2, False, 88.0],
    ['Bob', 35, 71.0, True, 76.5],
    ['Eve', 28, 65.8, False, 92.0],
    ['Charlie', 40, 72.3, False, 87.5]
]

column_names = ['Name', 'Age', 'Height (inches)', 'Is Student', 'Scores']

df = pd.DataFrame(data_list, columns=column_names, index=['A','B','C','D','E'])

# Display the DataFrame
df
# Out:
#       Name  Age  Height (inches)  Is Student  Scores
# A     John   30             68.5        True    95.5
# B    Alice   25             63.2       False    88.0
# C      Bob   35             71.0        True    76.5
# D      Eve   28             65.8       False    92.0
# E  Charlie   40             72.3       False    87.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             5 non-null      object
#  1   Age              5 non-null      int64
#  2   Height (inches)  5 non-null      float64
#  3   Is Student       5 non-null      bool
#  4   Scores           5 non-null      float64
# dtypes: bool(1), float64(2), int64(1), object(1)
# memory usage: 297.0+ bytes

# %%
data_dict = {
    'Name': ['John', 'Alice', 'Bob', 'Eve', 'Charlie'],
    'Age': [30, 25, 35, 28, 40],
    'Height (inches)': [68.5, 63.2, 71.0, 65.8, 72.3],
    'Is Student': [True, False, True, False, False],
    'Scores': [95.5, 88.0, 76.5, 92.0, 87.5]
}

df = pd.DataFrame(data_dict)

# %%
df
# Out:
#       Name  Age  Height (inches)  Is Student  Scores
# 0     John   30             68.5        True    95.5
# 1    Alice   25             63.2       False    88.0
# 2      Bob   35             71.0        True    76.5
# 3      Eve   28             65.8       False    92.0
# 4  Charlie   40             72.3       False    87.5

# %%
import opendatasets as od 
od.download("https://www.kaggle.com/datasets/utkarshtomar736/ipl-mens-cricket-matches-data-2008-2023")
# Out:
# Skipping, found downloaded files in ".\ipl-mens-cricket-matches-data-2008-2023" (use force=True to force download)

# %%
df = pd.read_csv("ipl-mens-cricket-matches-data-2008-2023//match_info_data.csv")

# %%
df.head()
# Out:
#         id season       city        date                team1  \
# 0  1370353   2023  Ahmedabad  2023/05/29       Gujarat Titans
# 1  1370352   2023  Ahmedabad  2023/05/26       Gujarat Titans
# 2  1370351   2023    Chennai  2023/05/24       Mumbai Indians
# 3  1370350   2023    Chennai  2023/05/23  Chennai Super Kings
# 4  1359543   2023     Mumbai  2023/05/21  Sunrisers Hyderabad
#
#                   team2          toss_winner toss_decision  result  \
# 0   Chennai Super Kings  Chennai Super Kings         field     D/L
# 1        Mumbai Indians       Mumbai Indians         field  normal
# 2  Lucknow Super Giants       Mumbai Indians           bat  normal
# 3        Gujarat Titans       Gujarat Titans         field  normal
# 4        Mumbai Indians       Mumbai Indians         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           1  Chennai Super Kings            0               5
# ...

# %%
df.tail()
# Out:
#           id   season        city        date                        team1  \
# 1019  335986  2007/08     Kolkata  2008/04/20        Kolkata Knight Riders
# 1020  335985  2007/08      Mumbai  2008/04/20               Mumbai Indians
# 1021  335984  2007/08       Delhi  2008/04/19             Delhi Daredevils
# 1022  335983  2007/08  Chandigarh  2008/04/19              Kings XI Punjab
# 1023  335982  2007/08   Bangalore  2008/04/18  Royal Challengers Bangalore
#
#                             team2                  toss_winner toss_decision  \
# 1019              Deccan Chargers              Deccan Chargers           bat
# 1020  Royal Challengers Bangalore               Mumbai Indians           bat
# 1021             Rajasthan Royals             Rajasthan Royals           bat
# 1022          Chennai Super Kings          Chennai Super Kings           bat
# 1023        Kolkata Knight Riders  Royal Challengers Bangalore         field
#
# ...

# %%
df.sample(5)
# Out:
#           id   season       city        date                        team1  \
# 26   1359522     2023     Jaipur  2023/05/05             Rajasthan Royals
# 589   734005     2014  Bangalore  2014/05/13  Royal Challengers Bangalore
# 704   548379     2012  Bangalore  2012/05/23          Chennai Super Kings
# 210  1237178  2020/21  Abu Dhabi  2020/11/06  Royal Challengers Bangalore
# 424  1082613     2017    Kolkata  2017/04/21        Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  result  \
# 26        Gujarat Titans     Rajasthan Royals           bat  normal
# 589     Delhi Daredevils     Delhi Daredevils         field  normal
# 704       Mumbai Indians       Mumbai Indians         field  normal
# 210  Sunrisers Hyderabad  Sunrisers Hyderabad         field  normal
# 424        Gujarat Lions        Gujarat Lions         field  normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.dtypes
# Out:
# id                  int64
# season             object
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
df.columns.to_list()
# Out:
# ['id',
#  'season',
#  'city',
#  'date',
#  'team1',
#  'team2',
#  'toss_winner',
#  'toss_decision',
#  'result',
#  'dl_applied',
#  'winner',
#  'win_by_runs',
#  'win_by_wickets',
#  'player_of_match',
#  'venue',
#  'umpire1',
#  'umpire2',
#  'umpire3']

# %%
df.isna().all()
# Out:
# id                 False
# season             False
# city               False
# date               False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# result             False
# dl_applied         False
# winner             False
# win_by_runs        False
# win_by_wickets     False
# player_of_match    False
# venue              False
# umpire1            False
# umpire2            False
# umpire3            False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                  0
# season              0
# city               51
# date                0
# team1               0
# team2               0
# toss_winner         0
# toss_decision       0
# result              0
# dl_applied          0
# winner             19
# win_by_runs         0
# win_by_wickets      0
# player_of_match     5
# venue               0
# umpire1             0
# umpire2             0
# umpire3             3
# dtype: int64

# %%
df.dropna(inplace =True)

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
df=df.rename(columns={'id':'ID'})

# %%
df.head()
# Out:
#         ID season       city        date                team1  \
# 0  1370353   2023  Ahmedabad  2023/05/29       Gujarat Titans
# 1  1370352   2023  Ahmedabad  2023/05/26       Gujarat Titans
# 2  1370351   2023    Chennai  2023/05/24       Mumbai Indians
# 3  1370350   2023    Chennai  2023/05/23  Chennai Super Kings
# 4  1359543   2023     Mumbai  2023/05/21  Sunrisers Hyderabad
#
#                   team2          toss_winner toss_decision  result  \
# 0   Chennai Super Kings  Chennai Super Kings         field     D/L
# 1        Mumbai Indians       Mumbai Indians         field  normal
# 2  Lucknow Super Giants       Mumbai Indians           bat  normal
# 3        Gujarat Titans       Gujarat Titans         field  normal
# 4        Mumbai Indians       Mumbai Indians         field  normal
#
#    dl_applied               winner  win_by_runs  win_by_wickets  \
# 0           1  Chennai Super Kings            0               5
# ...

# %%
data = {'Age': [25, 32, 45, 18, 63, 29, 55, 41, 37, 50]}
df = pd.DataFrame(data)

# Define bins for age groups
age_bins = [0, 18, 30, 40, 60, 100]
age_labels = ['<18', '18-30', '31-40', '41-60', '60+']

# Create a new column with age categories
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)

df
# Out:
#    Age Age Group
# 0   25     18-30
# 1   32     31-40
# 2   45     41-60
# 3   18       <18
# 4   63       60+
# 5   29     18-30
# 6   55     41-60
# 7   41     41-60
# 8   37     31-40
# 9   50     41-60

# %%
data = {'Scores': [70, 82, 60, 90, 78, 55, 88, 92, 75, 68]}
df = pd.DataFrame(data)

# Use qcut to create quantile-based bins
quantile_bins = pd.qcut(df['Scores'], q=3, labels=['Low', 'Medium', 'High'])

df['Score Category'] = quantile_bins

df
# Out:
#    Scores Score Category
# 0      70            Low
# 1      82         Medium
# 2      60            Low
# 3      90           High
# 4      78         Medium
# 5      55            Low
# 6      88           High
# 7      92           High
# 8      75         Medium
# 9      68            Low

# %%
data = {'Category': ['A', 'B', 'A', 'C', 'B']}
df = pd.DataFrame(data)

# Perform one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Category'])

# %%
df_encoded
# Out:
#    Category_A  Category_B  Category_C
# 0           1           0           0
# 1           0           1           0
# 2           1           0           0
# 3           0           0           1
# 4           0           1           0

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {'Year': [2010, 2011, 2012, 2013, 2014],
        'Sales': [100, 150, 200, 180, 250]}

df = pd.DataFrame(data)

df.plot(x='Year', y='Sales', kind='line')
plt.title('Yearly Sales')
plt.show()
